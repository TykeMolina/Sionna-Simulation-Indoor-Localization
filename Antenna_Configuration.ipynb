# %%
import numpy as np
import tensorflow as tf
import sionna
from sionna.rt import PlanarArray, Transmitter, Receiver

# %%
thetaSigma = 0.2
phiSigma = 1.0

thetaCenter = np.pi / 2.0
phiCenter = 0.0

gain = tf.exp(  )
